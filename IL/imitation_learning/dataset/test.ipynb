# %%
import pandas as pd

# %%
df = pd.read_csv("submissions.csv")
max_row = df.loc[df['score'].idxmax()]
submission_id = max_row['submission_id']
score = max_row['score']

print(submission_id)
# Out:
# 42613059
