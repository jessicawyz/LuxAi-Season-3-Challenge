# %%
from imitation_learning.train import main

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.9.0+cpu
# False

# %%
main([42613059, 42613183], 647)
# Out:
# total number of episodes: 831
# train size: 789
# val size: 42
# Epoch 1/50 | train | Loss: 0.46472 | Acc: 0.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 main([42613059, 42613183], 647)
#
# File c:\Users\Yang LiTing\Desktop\CS4246\Project\lux3-bot\imitation_learning\train.py:854, in main(submission_ids, min_opp_score)
#     851 # center, up, right, down, left, sap
#     852 weights = torch.Tensor([0.3, 1.0, 0.5, 0.5, 1.0, 1.0]).float()
# --> 854 train_model(
#     855     model,
#     856     train_episodes,
#     857     val_episodes,
#     858     optimizer,
#     859     scheduler,
#     860     weights,
#     861     num_epochs=50,
#     862     model_name=MODEL_NAME,
#     863 )
#
# ...
